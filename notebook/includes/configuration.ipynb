# %%
raw_folder_path = '/mnt/formula1dlsaga/raw'
processed_folder_path = '/mnt/formula1dlsaga/processed'
presentation_folder_path = '/mnt/formula1dlsaga/presentation'

# %%
# incase mounting option not available

#raw_folder_path = 'abfss://raw@formula1dlsaga.dfs.core.windows.net'
#processed_folder_path = 'abfss://processed@formula1dlsaga.dfs.core.windows.net'
#presentation_folder_path = 'abfss://presentation@formula1dlsaga.dfs.core.windows.net'
